# %%
from tkinter import *
root=Tk()
root.geometry('600x600')
def display():
    s1=e1.get()
    print(s1)
    l3=Label(root,text='Your Name is '+s1,font=('Times',21))
    l3.place(x=10,y=480)
    s2=e2.get()
    l4=Label(root,text='Your Password is '+s2,font=('Times',21))
    l4.place(x=10,y=450)
    print(s2)
l1=Label(root,text='Enter Your Name',font=('Times',21))
l1.place(x=10,y=70)
e1=Entry(root,font=('Times',21))
e1.place(x=280,y=70)
l2=Label(root,text='Enter Your Password',font=('Times',21))
l2.place(x=10,y=120)
e2=Entry(root,show='*',font=('Times',21))
e2.place(x=280,y=120)

l5=Label(root,text='Select City ',font=('Times',21))
l5.place(x=10,y=180)
s3=Spinbox(root,from_=0,to=10,font=('Times',21))
#s3.insert(1,'Mumbai')
s3.place(x=280,y=180)

l6=Label(root,text='Select Fav Sport ',font=('Times',21))
l6.place(x=10,y=280)
c1=Checkbutton(root,text='Football',font=('Times',21))
c1.place(x=220,y=280)
c2=Checkbutton(root,text='Cricket',font=('Times',21))
c2.place(x=360,y=280)
c3=Checkbutton(root,text='Tennis',font=('Times',21))
c3.place(x=490,y=280)


v1=IntVar()
l6=Label(root,text='Select Fav Sport ',font=('Times',21))
l6.place(x=10,y=360)
R1=Radiobutton(root,text='Male',variable=v1,value=1,font=('Times',21))
R1.place(x=280,y=360)
R2=Radiobutton(root,text='Female',variable=v1,value=2,font=('Times',21))
R2.place(x=380,y=360)




b1=Button(root,text='Submit',font=('Times',21),command=display)
b1.place(x=120,y=480)
b2=Button(root,text='Clear',font=('Times',21))
b2.place(x=290,y=480)

root.mainloop()

# %%
#set geometry
from tkinter import *
root=Tk()
root.geometry('600x600')
root.mainloop()

# %%
#set geometry
from tkinter import *
root=Tk()
root.geometry('1000x100')
root.mainloop()

# %%
#Label, text and placement
from tkinter import *
root=Tk()
root.geometry('600x600')
l1=Label(root,text='Enter Your Name',font=('Times',21))
#Co-ordinate of top left corner of text
l1.place(x=10,y=70)
root.mainloop()

# %%
#Entry font & placement
from tkinter import *
root=Tk()
root.geometry('600x600')
l1=Label(root,text='Enter Your Name',font=('Times',21))
# Co-ordinate of top left corner of text
l1.place(x=10,y=10)
# Co-ordinate of top left corner
e1=Entry(root,font=('Times',21))
e1.place(x=270,y=10)
root.mainloop()

# %%
#two lables & two entries
from tkinter import *
root=Tk()
root.geometry('600x600')
l1=Label(root,text='Enter Your Name',font=('Times',21))
# Co-ordinate of top left corner of text
l1.place(x=10,y=10)
# Co-ordinate of top left corner
e1=Entry(root,font=('Times',21))
e1.place(x=270,y=10)
l2=Label(root,text='Enter Your Password',font=('Times',21))
l2.place(x=10,y=50)
e2=Entry(root,show='*',font=('Times',21))
e2.place(x=270,y=50)
root.mainloop()

# %%
#Spinbox: creation, placement and choices
from tkinter import *
root=Tk()
root.geometry('600x600')

l1=Label(root,text='Enter Your Name',font=('Times',21))
# Co-ordinate of top left corner of text
l1.place(x=10,y=10)
# Co-ordinate of top left corner
e1=Entry(root,font=('Times',21))
e1.place(x=270,y=10)
l2=Label(root,text='Enter Your Password',font=('Times',21))
l2.place(x=10,y=50)
e2=Entry(root,show='*',font=('Times',21))
e2.place(x=270,y=50)

l5=Label(root,text='Select City ',font=('Times',21))
l5.place(x=10,y=90)
s3=Spinbox(root,font=('Times',21))
s3=Spinbox(root,from_=0,to=10,font=('Times',21))
s3.place(x=270,y=90)

root.mainloop()

# %%
#Checkbutton
from tkinter import *
root=Tk()
root.geometry('600x600')

l1=Label(root,text='Enter Your Name',font=('Times',21))
# Co-ordinate of top left corner of text
l1.place(x=10,y=10)
# Co-ordinate of top left corner
e1=Entry(root,font=('Times',21))
e1.place(x=270,y=10)

l2=Label(root,text='Enter Your Password',font=('Times',21))
l2.place(x=10,y=50)
e2=Entry(root,show='*',font=('Times',21))
e2.place(x=270,y=50)

l5=Label(root,text='Select City ',font=('Times',21))
l5.place(x=10,y=90)
s3=Spinbox(root,font=('Times',21))
s3=Spinbox(root,from_=0,to=10,font=('Times',21))
s3.place(x=270,y=90)

l6=Label(root,text='Select Fav Sport ',font=('Times',21))
l6.place(x=10,y=150)
c1=Checkbutton(root,text='Football',font=('Times',21))
c1.place(x=220,y=150)
c2=Checkbutton(root,text='Cricket',font=('Times',21))
c2.place(x=360,y=150)
c3=Checkbutton(root,text='Tennis',font=('Times',21))
c3.place(x=490,y=150)

root.mainloop()

# %%
#Radio button
from tkinter import *
root=Tk()
root.geometry('600x600')

l1=Label(root,text='Enter Your Name',font=('Times',21))
# Co-ordinate of top left corner of text
l1.place(x=10,y=10)
# Co-ordinate of top left corner
e1=Entry(root,font=('Times',21))
e1.place(x=270,y=10)

l2=Label(root,text='Enter Your Password',font=('Times',21))
l2.place(x=10,y=50)
e2=Entry(root,show='*',font=('Times',21))
e2.place(x=270,y=50)

l5=Label(root,text='Select City ',font=('Times',21))
l5.place(x=10,y=90)
s3=Spinbox(root,font=('Times',21))
s3=Spinbox(root,from_=0,to=10,font=('Times',21))
s3.place(x=270,y=90)

l6=Label(root,text='Select Fav Sport ',font=('Times',21))
l6.place(x=10,y=150)
c1=Checkbutton(root,text='Football',font=('Times',21))
c1.place(x=220,y=150)
c2=Checkbutton(root,text='Cricket',font=('Times',21))
c2.place(x=360,y=150)
c3=Checkbutton(root,text='Tennis',font=('Times',21))
c3.place(x=490,y=150)

#v1=IntVar()
l6=Label(root,text='Gender',font=('Times',21))
l6.place(x=10,y=190)
R1=Radiobutton(root,text='Male',value=1,font=('Times',21))
R1.place(x=280,y=190)
R2=Radiobutton(root,text='Female',value=2,font=('Times',21))
R2.place(x=380,y=190)

b1=Button(root,text='Submit',font=('Times',21),command=display)
b1.place(x=120,y=480)
b2=Button(root,text='Clear',font=('Times',21))
b2.place(x=290,y=480)

root.mainloop()

# %%
from tkinter import *
#import tkMessageBox
#import tkinter

top = Tk()
CheckVar1 = IntVar()
CheckVar2 = IntVar()
C1 = Checkbutton(top, text = "Music", variable = CheckVar1, \
     onvalue = 1, offvalue = 0, height=5, width = 20)
C2 = Checkbutton(top, text = "Video", variable = CheckVar2, \
     onvalue = 1, offvalue = 0, height=5, width = 20)
C1.pack()
C2.pack()
top.mainloop()

# %%
#Button
from tkinter import *
root=Tk()
root.geometry('600x600')
def display():
    s1=e1.get()
    print(s1)
    l3=Label(root,text='Your Name is '+s1,font=('Times',21))
    l3.place(x=10,y=250)
    s2=e2.get()
    l4=Label(root,text='Your Password is '+s2,font=('Times',21))
    l4.place(x=10,y=290)
    print(s2)

l1=Label(root,text='Enter Your Name',font=('Times',21))
# Co-ordinate of top left corner of text
l1.place(x=10,y=10)
# Co-ordinate of top left corner
e1=Entry(root,font=('Times',21))
e1.place(x=270,y=10)

l2=Label(root,text='Enter Your Password',font=('Times',21))
l2.place(x=10,y=50)
e2=Entry(root,show='*',font=('Times',21))
e2.place(x=270,y=50)

city=['Mumbai', 'Pune', 'Nashik', 'Kolhapur', 'Ratnagiri']
l5=Label(root,text='Select City ',font=('Times',21))
l5.place(x=10,y=90)
s3=Spinbox(root,values=city,width=10,font=('Times',21))
#s3.insert('1','Mumbai')
s3.place(x=270,y=90)

l6=Label(root,text='Select Fav Sport ',font=('Times',21))
l6.place(x=10,y=150)
c1=Checkbutton(root,text='Football',font=('Times',21))
c1.place(x=220,y=150)
c2=Checkbutton(root,text='Cricket',font=('Times',21))
c2.place(x=360,y=150)
c3=Checkbutton(root,text='Tennis',font=('Times',21))
c3.place(x=490,y=150)

#v1=IntVar()
l6=Label(root,text='Gender',font=('Times',21))
l6.place(x=10,y=190)
R1=Radiobutton(root,text='Male',value=1,font=('Times',21))
R1.place(x=280,y=190)
R2=Radiobutton(root,text='Female',value=2,font=('Times',21))
R2.place(x=380,y=190)

b1=Button(root,text='Submit',font=('Times',21),command=display)
b1.place(x=120,y=480)
b2=Button(root,text='Clear',font=('Times',21))
b2.place(x=290,y=480)

root.mainloop()

# %%
# Out:
# Opened database successfully
# Table Created successfully

# %%
import tkinter as tk
from tkinter import *
my_w = tk.Tk()
my_w.geometry("300x150")  # Size of the window 
my_w.title("www.plus2net.com")  # Adding a title

sb1 = Spinbox(my_w, from_= 0, to = 10,width=5)
sb1.grid(row=1,column=1,padx=20,pady=20)

my_list=['One', 'Two', 'Three', 'Four', 'Five']
sb2 = Spinbox(my_w,values=my_list,width=10)
sb2.grid(row=1,column=2,padx=20,pady=20)

my_w.mainloop()  # Keep the window open
